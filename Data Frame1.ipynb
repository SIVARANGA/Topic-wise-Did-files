# %%
import pandas as pd

# %% [markdown]
# # data frame

# %% [markdown]
# ### literally the only difference between read table and read CSV is that read CSV uses the comma as the default separator

# %% [markdown]
# ### Here the data is already in csv file so no need to use sep as comma,suppose if we use read_table we have to use sep.

# %%
#pd.read_table("http://bit.ly/uforeports,sep=",")
ufo=pd.read_csv("http://bit.ly/uforeports")

# %%
ufo
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# 5               Valley City             NaN           DISK    ND
# 6               Crater Lake             NaN         CIRCLE    CA
# 7                      Alma             NaN           DISK    MI
# 8                   Eklutna             NaN          CIGAR    AK
# 9                   Hubbard             NaN       CYLINDER    OR
# 10                  Fontana             NaN          LIGHT    CA
# 11                 Waterloo             NaN       FIREBALL    AL
# 12                   Belton             RED         SPHERE    SC
# ...

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
type(ufo)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### It displays the city column

# %%
ufo["City"]
# Out:
# 0                      Ithaca
# 1                 Willingboro
# 2                     Holyoke
# 3                     Abilene
# 4        New York Worlds Fair
# 5                 Valley City
# 6                 Crater Lake
# 7                        Alma
# 8                     Eklutna
# 9                     Hubbard
# 10                    Fontana
# 11                   Waterloo
# 12                     Belton
# 13                     Keokuk
# 14                  Ludington
# 15                Forest Home
# 16                Los Angeles
# 17                  Hapeville
# 18                     Oneida
# 19                 Bering Sea
# 20                   Nebraska
# 21                        NaN
# 22                        NaN
# 23                  Owensboro
# 24                 Wilderness
# 25                  San Diego
# 26                 Wilderness
# 27                     Clovis
# 28                 Los Alamos
# 29               Ft. Duschene
#                  ...
# ...

# %%
type(ufo["City"])
# Out:
# pandas.core.series.Series

# %%
ufo.City
# Out:
# 0                      Ithaca
# 1                 Willingboro
# 2                     Holyoke
# 3                     Abilene
# 4        New York Worlds Fair
# 5                 Valley City
# 6                 Crater Lake
# 7                        Alma
# 8                     Eklutna
# 9                     Hubbard
# 10                    Fontana
# 11                   Waterloo
# 12                     Belton
# 13                     Keokuk
# 14                  Ludington
# 15                Forest Home
# 16                Los Angeles
# 17                  Hapeville
# 18                     Oneida
# 19                 Bering Sea
# 20                   Nebraska
# 21                        NaN
# 22                        NaN
# 23                  Owensboro
# 24                 Wilderness
# 25                  San Diego
# 26                 Wilderness
# 27                     Clovis
# 28                 Los Alamos
# 29               Ft. Duschene
#                  ...
# ...

# %%
ufo.Colors Reported  #above it is showing error so,we have to use square brackets because it is taken into two words
# Out:
#   File "<ipython-input-16-823f97112488>", line 1
#     ufo.Colors Reported
#                       ^
# SyntaxError: invalid syntax

# %%
ufo["Colors Reported"]
# Out:
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 10          NaN
# 11          NaN
# 12          RED
# 13          NaN
# 14          NaN
# 15          NaN
# 16          NaN
# 17          NaN
# 18          NaN
# 19          RED
# 20          NaN
# 21          NaN
# 22          NaN
# 23          NaN
# 24          NaN
# 25          NaN
# 26          NaN
# 27          NaN
# 28          NaN
# 29          NaN
#           ...
# 18211       NaN
# 18212       NaN
# 18213     GREEN
# 18214       NaN
# 18215       NaN
# 18216    ORANGE
# 18217       NaN
# 18218       NaN
# 18219       NaN
# 18220      BLUE
# 18221       NaN
# 18222       NaN
# 18223       NaN
# 18224       NaN
# 18225       NaN
# 18226       NaN
# 18227       NaN
# 18228       NaN
# 18229       NaN
# 18230       NaN
# 18231       NaN
# 18232       NaN
# 18233       RED
# 18234       NaN
# ...

# %%
"ab"+"cd"
# Out:
# 'abcd'

# %%
ufo.City+' , '+ufo.State
# Out:
# 0                      Ithaca , NY
# 1                 Willingboro , NJ
# 2                     Holyoke , CO
# 3                     Abilene , KS
# 4        New York Worlds Fair , NY
# 5                 Valley City , ND
# 6                 Crater Lake , CA
# 7                        Alma , MI
# 8                     Eklutna , AK
# 9                     Hubbard , OR
# 10                    Fontana , CA
# 11                   Waterloo , AL
# 12                     Belton , SC
# 13                     Keokuk , IA
# 14                  Ludington , MI
# 15                Forest Home , CA
# 16                Los Angeles , CA
# 17                  Hapeville , GA
# 18                     Oneida , TN
# 19                 Bering Sea , AK
# 20                   Nebraska , NE
# 21                             NaN
# 22                             NaN
# 23                  Owensboro , KY
# 24                 Wilderness , WV
# 25                  San Diego , CA
# 26                 Wilderness , WV
# ...

# %% [markdown]
# ### To create a new series

# %%
ufo['location']=ufo.City+' , '+ufo.State
ufo['location']
# Out:
# 0                      Ithaca , NY
# 1                 Willingboro , NJ
# 2                     Holyoke , CO
# 3                     Abilene , KS
# 4        New York Worlds Fair , NY
# 5                 Valley City , ND
# 6                 Crater Lake , CA
# 7                        Alma , MI
# 8                     Eklutna , AK
# 9                     Hubbard , OR
# 10                    Fontana , CA
# 11                   Waterloo , AL
# 12                     Belton , SC
# 13                     Keokuk , IA
# 14                  Ludington , MI
# 15                Forest Home , CA
# 16                Los Angeles , CA
# 17                  Hapeville , GA
# 18                     Oneida , TN
# 19                 Bering Sea , AK
# 20                   Nebraska , NE
# 21                             NaN
# 22                             NaN
# 23                  Owensboro , KY
# 24                 Wilderness , WV
# 25                  San Diego , CA
# 26                 Wilderness , WV
# ...

# %% [markdown]
# ### Here we can see that location is added.

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time  \
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00
#
#                     location
# 0                Ithaca , NY
# 1           Willingboro , NJ
# 2               Holyoke , CO
# 3               Abilene , KS
# 4  New York Worlds Fair , NY

# %%
ufo.describe()
# Out:
#            City Colors Reported Shape Reported  State              Time  \
# count     18216            2882          15597  18241             18241
# unique     6476              27             27     52             16145
# top     Seattle             RED          LIGHT     CA  11/16/1999 19:00
# freq        187             780           2803   2529                27
#
#             location
# count          18216
# unique          8029
# top     Seattle , WA
# freq             187

# %% [markdown]
# ### Why do some pandas commands end with parentheses (and others don't)?

# %%
movies=pd.read_csv("http://bit.ly/imdbratings")

# %%
movies
# Out:
#      star_rating                                              title  \
# 0            9.3                           The Shawshank Redemption
# 1            9.2                                      The Godfather
# 2            9.1                             The Godfather: Part II
# 3            9.0                                    The Dark Knight
# 4            8.9                                       Pulp Fiction
# 5            8.9                                       12 Angry Men
# 6            8.9                     The Good, the Bad and the Ugly
# 7            8.9      The Lord of the Rings: The Return of the King
# 8            8.9                                   Schindler's List
# 9            8.9                                         Fight Club
# 10           8.8  The Lord of the Rings: The Fellowship of the Ring
# 11           8.8                                          Inception
# 12           8.8     Star Wars: Episode V - The Empire Strikes Back
# ...

# %%
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %% [markdown]
# ### described works is as long as there's at least one numeric column it will show you descriptive statistics

# %%
movies.describe()
# Out:
#        star_rating    duration
# count   979.000000  979.000000
# mean      7.889785  120.979571
# std       0.336069   26.218010
# min       7.400000   64.000000
# 25%       7.600000  102.000000
# 50%       7.800000  117.000000
# 75%       8.100000  134.000000
# max       9.300000  242.000000

# %%
movies.shape
# Out:
# (979, 6)

# %%
movies.dtypes
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %%
type(movies)
# Out:
# pandas.core.frame.DataFrame

# %%
movies.describe()
# Out:
#        star_rating    duration
# count   979.000000  979.000000
# mean      7.889785  120.979571
# std       0.336069   26.218010
# min       7.400000   64.000000
# 25%       7.600000  102.000000
# 50%       7.800000  117.000000
# 75%       8.100000  134.000000
# max       9.300000  242.000000

# %%
movies.describe(include=["object"])
# Out:
#             title content_rating  genre  \
# count         979            976    979
# unique        975             12     16
# top     True Grit              R  Drama
# freq            2            460    278
#
#                                               actors_list
# count                                                 979
# unique                                                969
# top     [u'Daniel Radcliffe', u'Emma Watson', u'Rupert...
# freq                                                    6

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 979 entries, 0 to 978
# Data columns (total 6 columns):
# star_rating       979 non-null float64
# title             979 non-null object
# content_rating    976 non-null object
# genre             979 non-null object
# duration          979 non-null int64
# actors_list       979 non-null object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 46.0+ KB

# %%
movies.columns
# Out:
# Index(['star_rating', 'title', 'content_rating', 'genre', 'duration',
#        'actors_list'],
#       dtype='object')

# %%
movies.values
# Out:
# array([[9.3, 'The Shawshank Redemption', 'R', 'Crime', 142,
#         "[u'Tim Robbins', u'Morgan Freeman', u'Bob Gunton']"],
#        [9.2, 'The Godfather', 'R', 'Crime', 175,
#         "[u'Marlon Brando', u'Al Pacino', u'James Caan']"],
#        [9.1, 'The Godfather: Part II', 'R', 'Crime', 200,
#         "[u'Al Pacino', u'Robert De Niro', u'Robert Duvall']"],
#        ...,
#        [7.4, 'Master and Commander: The Far Side of the World', 'PG-13',
#         'Action', 138,
#         "[u'Russell Crowe', u'Paul Bettany', u'Billy Boyd']"],
#        [7.4, 'Poltergeist', 'PG', 'Horror', 114,
#         '[u\'JoBeth Williams\', u"Heather O\'Rourke", u\'Craig T. Nelson\']'],
#        [7.4, 'Wall Street', 'R', 'Crime', 126,
#         "[u'Charlie Sheen', u'Michael Douglas', u'Tamara Tunie']"]],
#       dtype=object)

# %%
movies.set_index("title",inplace=True)
movies.head()
# Out:
#                           star_rating content_rating   genre  duration  \
# title
# The Shawshank Redemption          9.3              R   Crime       142
# The Godfather                     9.2              R   Crime       175
# The Godfather: Part II            9.1              R   Crime       200
# The Dark Knight                   9.0          PG-13  Action       152
# Pulp Fiction                      8.9              R   Crime       154
#
#                                                                 actors_list
# title
# The Shawshank Redemption  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# The Godfather               [u'Marlon Brando', u'Al Pacino', u'James Caan']
# The Godfather: Part II    [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# The Dark Knight           [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# Pulp Fiction              [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies.sort_index(axis=1,ascending=False)
# Out:
#                                                    star_rating      genre  \
# title
# The Shawshank Redemption                                   9.3      Crime
# The Godfather                                              9.2      Crime
# The Godfather: Part II                                     9.1      Crime
# The Dark Knight                                            9.0     Action
# Pulp Fiction                                               8.9      Crime
# 12 Angry Men                                               8.9      Drama
# The Good, the Bad and the Ugly                             8.9    Western
# The Lord of the Rings: The Return of the King              8.9  Adventure
# Schindler's List                                           8.9  Biography
# Fight Club                                                 8.9      Drama
# The Lord of the Rings: The Fellowship of the Ring          8.8  Adventure
# Inception                                                  8.8     Action
# ...

# %%
movies.sort_index(axis=1,ascending=False)
# Out:
#                                                    star_rating      genre  \
# title
# The Shawshank Redemption                                   9.3      Crime
# The Godfather                                              9.2      Crime
# The Godfather: Part II                                     9.1      Crime
# The Dark Knight                                            9.0     Action
# Pulp Fiction                                               8.9      Crime
# 12 Angry Men                                               8.9      Drama
# The Good, the Bad and the Ugly                             8.9    Western
# The Lord of the Rings: The Return of the King              8.9  Adventure
# Schindler's List                                           8.9  Biography
# Fight Club                                                 8.9      Drama
# The Lord of the Rings: The Fellowship of the Ring          8.8  Adventure
# Inception                                                  8.8     Action
# ...

# %%
movies.sort_values(by="star_rating",ascending=True).head()
# Out:
#              star_rating content_rating   genre  duration  \
# title
# Wall Street          7.4              R   Crime       126
# Bound                7.4              R   Crime       108
# Home Alone           7.4             PG  Comedy       103
# Frances Ha           7.4              R  Comedy        86
# Eraserhead           7.4        UNRATED   Drama        89
#
#                                                    actors_list
# title
# Wall Street  [u'Charlie Sheen', u'Michael Douglas', u'Tamar...
# Bound        [u'Jennifer Tilly', u'Gina Gershon', u'Joe Pan...
# Home Alone   [u'Macaulay Culkin', u'Joe Pesci', u'Daniel St...
# Frances Ha   [u'Greta Gerwig', u'Mickey Sumner', u'Adam Dri...
# Eraserhead   [u'Jack Nance', u'Charlotte Stewart', u'Allen ...

# %%
movies.sort_index(axis=1).head()
# Out:
#                                                                 actors_list  \
# title
# The Shawshank Redemption  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# The Godfather               [u'Marlon Brando', u'Al Pacino', u'James Caan']
# The Godfather: Part II    [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# The Dark Knight           [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# Pulp Fiction              [u'John Travolta', u'Uma Thurman', u'Samuel L....
#
#                          content_rating  duration   genre  star_rating
# title
# The Shawshank Redemption              R       142   Crime          9.3
# The Godfather                         R       175   Crime          9.2
# The Godfather: Part II                R       200   Crime          9.1
# The Dark Knight                   PG-13       152  Action          9.0
# Pulp Fiction                          R       154   Crime          8.9

# %%
movies.sort_values(by=["star_rating","duration"],ascending=True).head()
# Out:
#                      star_rating content_rating      genre  duration  \
# title
# Alice in Wonderland          7.4              G  Animation        75
# Frances Ha                   7.4              R     Comedy        86
# The Simpsons Movie           7.4          PG-13  Animation        87
# Eraserhead                   7.4        UNRATED      Drama        89
# Death at a Funeral           7.4              R     Comedy        90
#
#                                                            actors_list
# title
# Alice in Wonderland  [u'Kathryn Beaumont', u'Ed Wynn', u'Richard Ha...
# Frances Ha           [u'Greta Gerwig', u'Mickey Sumner', u'Adam Dri...
# The Simpsons Movie   [u'Dan Castellaneta', u'Julie Kavner', u'Nancy...
# Eraserhead           [u'Jack Nance', u'Charlotte Stewart', u'Allen ...
# Death at a Funeral   [u'Matthew Macfadyen', u'Peter Dinklage', u'Ew...

# %%
movies.iloc[2,3]# 2nd row and 3rd column,position
# Out:
# 200

# %%
movies.iloc[5]#5th row
# Out:
# star_rating                                                     8.9
# content_rating                                            NOT RATED
# genre                                                         Drama
# duration                                                         96
# actors_list       [u'Henry Fonda', u'Lee J. Cobb', u'Martin Bals...
# Name: 12 Angry Men, dtype: object

# %%
movies.loc[3,"content_rating"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-9432a8c0ea0c> in <module>
# ----> 1 movies.loc[3,"content_rating"]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1492             except (KeyError, IndexError, AttributeError):
#    1493                 pass
# -> 1494             return self._getitem_tuple(key)
#    1495         else:
#    1496             # we by definition only have the 0th axis
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#     866     def _getitem_tuple(self, tup):
#     867         try:
# --> 868             return self._getitem_lowerdim(tup)
#     869         except IndexingError:
#     870             pass
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_lowerdim(self, tup)
# ...

# %%
movies.loc[5,:]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-362bed45af29> in <module>
# ----> 1 movies.loc[5,:]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1492             except (KeyError, IndexError, AttributeError):
#    1493                 pass
# -> 1494             return self._getitem_tuple(key)
#    1495         else:
#    1496             # we by definition only have the 0th axis
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#     866     def _getitem_tuple(self, tup):
#     867         try:
# --> 868             return self._getitem_lowerdim(tup)
#     869         except IndexingError:
#     870             pass
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_lowerdim(self, tup)
# ...

# %% [markdown]
# ## How do I rename columns in a pandas DataFrame
